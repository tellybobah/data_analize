# %%
install.packages('xtable')
data <- read.csv("1791077_1792552_1841782.csv", header = TRUE);
# Out:
# Installing package into ‘/home/telly/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# Warning message:
# “unable to access index for repository https://cran.r-project.org/src/contrib:
#   cannot open URL 'https://cran.r-project.org/src/contrib/PACKAGES'”Warning message:
# “package ‘xtable’ is not available (for R version 3.4.2)”

# %%
#Stockages des valeurs dans les variables
Age <- data$Age
ATOI <- data$ATOI
Salaire <- data$Salaire
Poids <- data$Poids
Taille <- data$Taille
Pos <- data$Pos

# %% [markdown]
# print(ATOI)

# %%
library(lubridate)
times <- data$ATOI
as.period(hms(times), unit = "sec")
atoi_seconds <- as.numeric(as.period(hms(times), unit = "sec"))
# Out:
#  [1] "39240S" "28500S" "37080S" "23580S" "24660S" "15180S" "41640S" "10740S"
#  [9] "41700S" "9840S"  "16080S" "15180S" "36540S" "39720S" "11280S" "12420S"
# [17] "19980S" "15420S" "5640S"  "39720S" "4440S"  "42180S" "24960S" "30240S"
# [25] "20280S" "13980S" "16500S" "57660S" "79800S" "32040S" "39060S" "58800S"
# [33] "34920S" "34440S" "78240S" "22320S" "62580S" "58080S" "58980S" "51780S"
# [41] "82920S" "42960S" "71340S" "49620S" "47280S" "39660S" "65820S" "78600S"
# [49] "60540S" "41340S" "35580S" "40320S" "42840S" "77340S" "61260S" "21180S"
# [57] "63180S"

# %%
#Conversion du temps en second pour garder la consistence des valeures
for(i in 1:length(atoi_seconds)){
    atoi_seconds[i] = atoi_seconds[i]/60
}

# %%
print(atoi_seconds)
# Out:
#  [1]  654  475  618  393  411  253  694  179  695  164  268  253  609  662  188
# [16]  207  333  257   94  662   74  703  416  504  338  233  275  961 1330  534
# [31]  651  980  582  574 1304  372 1043  968  983  863 1382  716 1189  827  788
# [46]  661 1097 1310 1009  689  593  672  714 1289 1021  353 1053

# %%
hist(atoi_seconds)
# Out:
# Plot with title “Histogram of atoi_seconds”

# %%
hist(Age)
# Out:
# Plot with title “Histogram of Age”

# %%
hist(Taille,freq = FALSE)
lines(density(Taille), lwd=4) # densité ajustée, lwd donne épaisseur de ligne
x = seq(0,18,length.out=500) # crée une séquence de 500 points entre 0 et 18

# densité d'une loi normale
lines(x, dnorm(x, mean(Taille), sd(Taille)), lwd=2, lty=3) 
# lty (line type) indique le type de ligne (pointillés, pleine...etc)
# Out:
# Plot with title “Histogram of Taille”

# %% [markdown]
# # Est-ce que la position du joueur influence son salaire  ?
#  faisons le modele de regression lineaire pour valider cette hipothese

# %%
# creating the factor variable
Pos.f <- factor(Pos)
is.factor(Pos.f)
print(Pos.f)
# Out:
# [1] TRUE
#  [1] D  G  C  D  D  RW LW C  D  RW D  RW RW G  D  D  C  C  LW C  G  D  G  C  C
# [26] LW C  C  D  LW RW D  C  G  G  G  C  C  C  LW D  C  D  LW D  RW RW D  C  RW
# [51] LW G  LW D  D  LW G
# Levels: C D G LW RW

# %%
reg <-lm(Salaire ~ Pos.f, data = data)
summary(reg)
# Out:
# Call:
# lm(formula = Salaire ~ Pos.f, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.977 -15.022  -8.272  15.928  48.273
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   24.272      5.512   4.404 5.33e-05 ***
# Pos.fD         7.455      7.672   0.972    0.336
# Pos.fG       -10.077      9.001  -1.120    0.268
# Pos.fLW       -5.199      9.001  -0.578    0.566
# Pos.fRW       -5.500      9.346  -0.588    0.559
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 21.35 on 52 degrees of freedom
# Multiple R-squared:  0.08568,	Adjusted R-squared:  0.01535
# F-statistic: 1.218 on 4 and 52 DF,  p-value: 0.3144

# %%
VARIABLE=c("",gsub("[-^0-9]", "", names(unlist(reg$xlevels))))
MODALITY=c("",as.character(unlist(reg$xlevels)))
names=data.frame(VARIABLE,MODALITY,NOMVAR=c( "(Intercept)",paste(VARIABLE,MODALITY,sep="")[-1]))
regression=data.frame(NOMVAR=names(coefficients(reg)),
COEF=as.numeric(coefficients(reg)))
merge(names,regression,all.x=TRUE)
# Out:
#   NOMVAR      VARIABLE MODALITY COEF
# 1 (Intercept)                    24.271667
# 2 Pos.fC      Pos.f    C                NA
# 3 Pos.fD      Pos.f    D          7.455208
# 4 Pos.fG      Pos.f    G        -10.077222
# 5 Pos.fLW     Pos.f    LW        -5.199444
# 6 Pos.fRW     Pos.f    RW        -5.499792

# %%
print(Salaire)
merge(names,regression)
# Out:
#  [1]  6.250 17.000  9.250  7.425 40.000 45.000  9.000  9.250 48.380  9.500
# [11] 10.250  9.250  9.250  5.750  5.750 80.000 50.000 30.000 21.250 16.000
# [21] 10.000  6.250 13.000  9.250  9.250 50.000 50.000  9.250 50.000 35.000
# [31]  7.425  6.500  8.325 50.000  7.500  8.500 50.000 11.000 23.500  7.500
# [41] 75.000  9.000 49.000 30.000  7.000  5.750 57.500 42.500 70.000  6.500
# [51]  6.000  9.500  6.400 65.000  8.325  6.500  6.500
#   NOMVAR      VARIABLE MODALITY COEF
# 1 (Intercept)                    24.271667
# 2 Pos.fD      Pos.f    D          7.455208
# 3 Pos.fG      Pos.f    G        -10.077222
# 4 Pos.fLW     Pos.f    LW        -5.199444
# 5 Pos.fRW     Pos.f    RW        -5.499792

# %% [markdown]
# Nous allons donc expliquer comment nous avons reussi a faire une regression lineaire avec une variable qui n'est pas numerique. La technique est bien simple il suffit de separer les differents poste en classe ainsi avec factor, nous allons assigner pour chaque poste une valeur numerique. Nous allons donc avoir
# C =1
# D =2
# G =3
# LW =4
# RW =5
#
# On peut voir le modele de regression grace au tableu ci dessous on peut donc en deduire que :
#
#
# \begin{equation*}
# Salaire   \approx 24.27 + Pos * Coef
# \end{equation*}

# %%
plot(reg)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# À la lumière des résultats précédents, on peut déterminer que la relation linéaire n’est pas
# significative.Nous ne pouvons pas determiner une corealatio entre le salaire et la position du joueur. Cela peut
# pricipalement etre du au peu de valeur que nous avons dans le cadre du projet. Pour une soixantaine de valeur,
# il est tres difficile d'estimer un modele de regression. De plus, on constate aussi que nous certains poste ne sont present que 3 a quatre fois. Il  y'a alors des classes absente et cela fausse notre resultat

# %% [markdown]
# # Est-ce que les joueurs avec le plus de temps sur la glace sont mieux rémunérés ?

# %% [markdown]
# Pour repondre a cette question , nous allons essayer d'effectuer un modele de regression lineaire entre ces deux
# variable aleatoires.

# %%
regression_2 <- lm(atoi_seconds ~ Salaire)
summary(regression_2)
# Out:
# Call:
# lm(formula = atoi_seconds ~ Salaire)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -664.60 -259.20   38.62  272.59  713.59
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  561.326     67.497   8.316 2.67e-11 ***
# Salaire        3.878      2.143   1.810   0.0758 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 345 on 55 degrees of freedom
# Multiple R-squared:  0.0562,	Adjusted R-squared:  0.03904
# F-statistic: 3.275 on 1 and 55 DF,  p-value: 0.07579

# %%
plot(regression_2)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# # Est-ce qu’un joueur plus jeune gagne moins d’argent annuellement qu’un joueur plus vieux ? Pour determiner cela nous allons effectuer une regression linéaire pour essayer de determiner

# %% [markdown]
# # Est-ce que les joueurs avec le même poste sont enclins à avoir les mêmes caractéristiques (poids et tailles) ?

# %% [markdown]
# # ESTIMATIONS DES PARAMETRES

# %%
shapiro.test(Salaire)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  Salaire
# W = 0.76825, p-value = 4.242e-08

# %%
# Out:
# [1] 23.18035

# %% [markdown]
# Selon une etude faites par le forbes  https://www.forbes.com/sites/kurtbadenhausen/2016/12/15/average-player-salaries-in-major-american-sports-leagues/#4e2df7e01050 en 2016, le salaire moyen d'un joueur du hockey est d'enrivon  $2.9 millios.
# Nous allons donc revifier si nous pouvons confirmer cette hypthese grace a notre echantillons de joueurs du canada

# %% [markdown]
# Ponsons :
#
# $
# H0 = 29 \\
# H1 \neq 29
# $

# %%
t.test(Salaire-29,alternative="two.sided",conf.level=0.95)
# Out:
# 	One Sample t-test
#
# data:  Salaire - 29
# t = -2.0424, df = 56, p-value = 0.04584
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  -11.5278477  -0.1114506
# sample estimates:
# mean of x
# -5.819649

# %%
Avec un intervale de confiance a 95%, nous pouvons refuter l'idee que la moyenne soit de 2.9 millions de dollards

# %%
shapiro.test(atoi_seconds)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  atoi_seconds
# W = 0.95774, p-value = 0.04463

# %%
shapiro.test(Taille)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  Taille
# W = 0.9549, p-value = 0.03296

# %%
shapiro.test(Poids)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  Poids
# W = 0.96565, p-value = 0.105

# %%
mean(Poids)
# Out:
# [1] 91.22281
